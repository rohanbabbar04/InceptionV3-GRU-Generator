# %%
import string
import pickle
import numpy as np
from PIL import Image
import os
from pickle import dump, load
import numpy as np
import tqdm
from tensorflow import keras
import tensorflow as tf

from keras.applications.xception import Xception, preprocess_input
from keras.applications import InceptionV3

from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import load_img, img_to_array
from keras.layers import Concatenate

from keras.models import Model, load_model
from keras.layers import Input, Dense, LSTM, Embedding, Dropout, GRU

# %% [markdown]
# ## Getting and performing data cleaning

# %%
def load_doc(filename):
    with open(filename, 'r') as file:
        return file.read()

def img_captions(filename):
    with open(filename, 'r') as file:
        lines = file.read().strip().split('\n')
    descriptions = {}
    for line in lines:
        img, caption = line.split('\t')
        img_key = img[:-2]

        if img_key not in descriptions:
            descriptions[img_key] = [caption]
        else:
            descriptions[img_key].append(caption)
    return descriptions

def preprocess_captions(captions):
    table = str.maketrans('', '', string.punctuation)

    for img, caps in captions.items():
        captions[img] = [
            ' '.join(filter(lambda w: w.isalpha() and len(w) > 1, word.translate(table).lower().replace("-", " ").split()))
            for word in caps
        ]
    return captions

def get_vocabulary(descriptions):
    return set(word for key in descriptions for d in descriptions[key] for word in d.split())

def save_descriptions(descriptions, filename):
    lines = []
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + '\t' + desc)
    data = "\n".join(lines)
    with open(filename, "w") as file:
        file.write(data)

# %%
dataset_images = "data/Flicker8k_Dataset/"
filename = "data/Flickr8k.token.txt"
descriptions = all_img_captions(filename)
print("Length of descriptions =" , len(descriptions))

clean_descriptions = cleaning_text(descriptions)

vocabulary = text_vocabulary(clean_descriptions)
print("Length of vocabulary = ", len(vocabulary))

save_descriptions(clean_descriptions, "data/descriptions.txt")
# Out:
# Length of descriptions = 8092
# Length of vocabulary =  8422

# %% [markdown]
# ## Extracting the feature vector from all images

# %%
def extract_features(directory):
        model = InceptionV3(include_top=False, pooling='avg')
        features = {}
        for img in os.listdir(directory):
            img_path = os.path.join(directory, img)
            with Image.open(img_path) as image:
                image = image.resize((299, 299))
                image = np.expand_dims(image, axis=0)
                image = (image / 127.5) - 1.0
                feature = model.predict(image)
                features[img] = feature
        return features
features = extract_features(dataset_images)
dump(features, open("data/features.p","wb"))
# Out:
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 63ms/step
# ...
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 130ms/step

# %%
features = load(open("data/features.p","rb"))

# %%
len(features)
# Out:
# 8091

# %% [markdown]
# ## Loading dataset for Training the model

# %%
#load the data 
def load_photos(filename):
    return load_doc(filename).split("\n")[:-1]

def load_clean_descriptions(filename, photos):
    """
    Load and clean descriptions from the specified file for the given photos.
    Returns:
    - A dictionary containing image filenames as keys and a list of cleaned descriptions as values.
    """
    file_content = load_doc(filename)
    descriptions = {}
    for line in file_content.split("\n"):
        words = line.split()
        if len(words) < 2:
            continue
        image, image_caption = words[0], words[1:]
        if image in photos:
            if image not in descriptions:
                descriptions[image] = []
            desc = '<start> ' + " ".join(image_caption) + ' <end>'
            descriptions[image].append(desc)
    return descriptions


def load_features(photos):
    all_features = pickle.load(open("data/features.p","rb"))
    features = {k:all_features[k] for k in photos}
    return features



filename = "data/Flickr_8k.trainImages.txt"

#train = loading_data(filename)
train_imgs = load_photos(filename)
train_descriptions = load_clean_descriptions("data/descriptions.txt", train_imgs)
train_features = load_features(train_imgs)

# %% [markdown]
# ## Tokenizing the vocabulary

# %%
train_descriptions
# Out:
# {'1000268201_693b08cb0e.jpg': ['<start> child in pink dress is climbing up set of stairs in an entry way <end>',
#   '<start> girl going into wooden building <end>',
#   '<start> little girl climbing into wooden playhouse <end>',
#   '<start> little girl climbing the stairs to her playhouse <end>',
#   '<start> little girl in pink dress going into wooden cabin <end>'],
#  '1001773457_577c3a7d70.jpg': ['<start> black dog and spotted dog are fighting <end>',
#   '<start> black dog and tri colored dog playing with each other on the road <end>',
#   '<start> black dog and white dog with brown spots are staring at each other in the street <end>',
#   '<start> two dogs of different breeds looking at each other on the road <end>',
#   '<start> two dogs on pavement moving toward each other <end>'],
#  '1002674143_1b742ab4b8.jpg': ['<start> little girl covered in paint sits in front of painted rainbow with her hands in bowl <end>',
#   '<start> little girl is sitting in front of large painted rainbow <end>',
#   '<start> small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it <end>',
#   '<start> there is girl with pigtails sitting in front of rainbow painting <end>',
#   '<start> young girl with pigtails painting outside in the grass <end>'],
#  '1003163366_44323f5815.jpg': ['<start> man lays on bench while his dog sits by him <end>',
#   '<start> man lays on the bench to which white dog is also tied <end>',
#   '<start> man sleeping on bench outside with white and black dog sitting next to him <end>',
#   '<start> shirtless man lies on park bench with his dog <end>',
#   '<start> man laying on bench holding leash of dog sitting on ground <end>'],
#  '1007129816_e794419615.jpg': ['<start> man in an orange hat starring at something <end>',
#   '<start> man wears an orange hat and glasses <end>',
#   '<start> man with gauges and glasses is wearing blitz hat <end>',
#   '<start> man with glasses is wearing beer can crocheted hat <end>',
#   '<start> the man with pierced ears is wearing glasses and an orange hat <end>'],
#  '1007320043_627395c3d8.jpg': ['<start> child playing on rope net <end>',
#   '<start> little girl climbing on red roping <end>',
#   '<start> little girl in pink climbs rope bridge at the park <end>',
#   '<start> small child grips onto the red ropes at the playground <end>',
#   '<start> the small child climbs on red ropes on playground <end>'],
#  '1009434119_febe49276a.jpg': ['<start> black and white dog is running in grassy garden surrounded by white fence <end>',
#   '<start> black and white dog is running through the grass <end>',
#   '<start> boston terrier is running in the grass <end>',
#   '<start> boston terrier is running on lush green grass in front of white fence <end>',
#   '<start> dog runs on the green grass near wooden fence <end>'],
#  '1012212859_01547e3f17.jpg': ['<start> dog shakes its head near the shore red ball next to it <end>',
#   '<start> white dog shakes on the edge of beach with an orange ball <end>',
#   '<start> dog with orange ball at feet stands on shore shaking off water <end>',
#   '<start> white dog playing with red ball on the shore near the water <end>',
#   '<start> white dog with brown ears standing near water with head turned to one side <end>'],
#  '1015118661_980735411b.jpg': ['<start> boy smiles in front of stony wall in city <end>',
#   '<start> little boy is standing on the street while man in overalls is working on stone wall <end>',
#   '<start> young boy runs aross the street <end>',
#   '<start> young child is walking on stone paved street with metal pole and man behind him <end>',
#   '<start> smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him <end>'],
#  '1015584366_dfcec3c85a.jpg': ['<start> black dog leaps over log <end>',
#   '<start> grey dog is leaping over fallen tree <end>',
#   '<start> large black dog leaps fallen log <end>',
#   '<start> mottled black and grey dog in blue collar jumping over fallen tree <end>',
#   '<start> the black dog jumped the tree stump <end>'],
#  '101654506_8eb26cfb60.jpg': ['<start> brown and white dog is running through the snow <end>',
#   '<start> dog is running in the snow <end>',
#   '<start> dog running through snow <end>',
#   '<start> white and brown dog is running through snow covered field <end>',
#   '<start> the white and brown dog is running over the surface of the snow <end>'],
#  '101669240_b2d3e7f17b.jpg': ['<start> man in hat is displaying pictures next to skier in blue hat <end>',
#   '<start> man skis past another man displaying paintings in the snow <end>',
#   '<start> person wearing skis looking at framed pictures set up in the snow <end>',
#   '<start> skier looks at framed pictures in the snow next to trees <end>',
#   '<start> man on skis looking at artwork for sale in the snow <end>'],
#  '1016887272_03199f49c4.jpg': ['<start> collage of one person climbing cliff <end>',
#   '<start> group of people are rock climbing on rock climbing wall <end>',
#   '<start> group of people climbing rock while one man belays <end>',
#   '<start> seven climbers are ascending rock face whilst another man stands holding the rope <end>',
#   '<start> several climbers in row are climbing the rock while the man in red watches and holds the line <end>'],
#  '1019077836_6fc9b15408.jpg': ['<start> brown dog chases the water from sprinkler on lawn <end>',
#   '<start> brown dog plays with the hose <end>',
#   '<start> brown dog running on lawn near garden hose <end>',
#   '<start> dog is playing with hose <end>',
#   '<start> large brown dog running away from the sprinkler in the grass <end>'],
#  '1019604187_d087bf9a5f.jpg': ['<start> dog prepares to catch thrown object in field with nearby cars <end>',
#   '<start> white dog is about to catch yellow ball in its mouth <end>',
#   '<start> white dog is about to catch yellow dog toy <end>',
#   '<start> white dog is ready to catch yellow ball flying through the air <end>',
#   '<start> white dog running after yellow ball <end>'],
#  '1020651753_06077ec457.jpg': ['<start> black and white dog jumping in the air to get toy <end>',
#   '<start> black and white dog jumps up towards yellow toy <end>',
#   '<start> dog leaps to catch ball in field <end>',
#   '<start> white dog is trying to catch ball in midair over grassy field <end>',
#   '<start> the white dog is playing in green field with yellow toy <end>'],
#  '1022454428_b6b660a67b.jpg': ['<start> couple and an infant being held by the male sitting next to pond with near by stroller <end>',
#   '<start> couple sit on the grass with baby and stroller <end>',
#   '<start> couple with their newborn baby sitting under tree facing lake <end>',
#   '<start> man and woman care for an infant along the side of body of water <end>',
#   '<start> couple with baby sit outdoors next to their stroller <end>'],
#  '1022975728_75515238d8.jpg': ['<start> black dog running in the surf <end>',
#   '<start> black lab with tags frolicks in the water <end>',
#   '<start> dog splashes in the water <end>',
#   '<start> the black dog runs through the water <end>',
#   '<start> this is black dog splashing in the water <end>'],
#  '102351840_323e3de834.jpg': ['<start> man drilling hole in the ice <end>',
#   '<start> man is drilling through the frozen ice of pond <end>',
#   '<start> person in the snow drilling hole in the ice <end>',
#   '<start> person standing on frozen lake <end>',
#   '<start> two men are ice fishing <end>'],
#  '1024138940_f1fefbdce1.jpg': ['<start> two different breeds of brown and white dogs play on the beach <end>',
#   '<start> two dogs are making turn on soft sand beach <end>',
#   '<start> two dogs playing in the sand at the beach <end>',
#   '<start> two dogs playing together on beach <end>',
#   '<start> two large tan dogs play along sandy beach <end>'],
#  '102455176_5f8ead62d5.jpg': ['<start> man uses ice picks and crampons to scale ice <end>',
#   '<start> an ice climber in blue jacket and black pants is scaling frozen ice wall <end>',
#   '<start> an ice climber scaling frozen waterfall <end>',
#   '<start> person in blue and red ice climbing with two picks <end>',
#   '<start> climber climbing an ice wall <end>'],
#  '1026685415_0431cbf574.jpg': ['<start> black dog carries green toy in his mouth as he walks through the grass <end>',
#   '<start> black dog carrying something through the grass <end>',
#   '<start> black dog has blue toy in its mouth <end>',
#   '<start> dog in grass with blue item in his mouth <end>',
#   '<start> wet black dog is carrying green toy through the grass <end>'],
#  '1028205764_7e8df9a2ea.jpg': ['<start> man and baby are in yellow kayak on water <end>',
#   '<start> man and little boy in blue life jackets are rowing yellow canoe <end>',
#   '<start> man and child kayak through gentle waters <end>',
#   '<start> man and young boy ride in yellow kayak <end>',
#   '<start> man and child in yellow kayak <end>'],
#  '1030985833_b0902ea560.jpg': ['<start> black dog and brown dog are jumping up to catch red toy <end>',
#   '<start> black dog and brown dog play with red toy on courtyard <end>',
#   '<start> brown and black lab are outside and the black lab is catching toy in its mouth <end>',
#   '<start> black dog snaps at red and black object as brown dog lunges <end>',
#   '<start> the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway <end>'],
#  '103195344_5d2dc613a3.jpg': ['<start> man in black is sitting next to modern art structure in front of glass building <end>',
#   '<start> man sits and reads newspaper by sculpture outside of an office building <end>',
#   '<start> man sits near large statue <end>',
#   '<start> man sitting in front of metal sculpture in front of building <end>',
#   '<start> the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading <end>'],
#  '103205630_682ca7285b.jpg': ['<start> tent is being set up on the ice <end>',
#   '<start> two men are about to enter an ice fishing tent on snow covered lake <end>',
#   '<start> two men setting up blue ice fishing hut on an iced over lake <end>',
#   '<start> two men standing on an ice looking into something covered with blue tarp <end>',
#   '<start> two people standing outside blue tent structure on snowy surface <end>'],
#  '1032460886_4a598ed535.jpg': ['<start> man is standing in front of skyscraper <end>',
#   '<start> man stands in front of skyscraper <end>',
#   '<start> man stands in front of very tall building <end>',
#   '<start> behind the man in red shirt stands large skyscraper <end>',
#   '<start> there is skyscraper in the distance with man walking in front of the camera <end>'],
#  '104136873_5b5d41be75.jpg': ['<start> people sit on the mountainside and check out the view <end>',
#   '<start> three people are on hilltop overlooking green valley <end>',
#   '<start> three people hang out on top of big hill <end>',
#   '<start> three people overlook green valley <end>',
#   '<start> three people rest on ledge above the moutains <end>'],
#  '1042020065_fb3d3ba5ba.jpg': ['<start> boy in green shirt is looking down at many inflatable boats <end>',
#   '<start> boy in green shirt watches kayakers <end>',
#   '<start> boy looks over railing at the many boats and rafts below in the water <end>',
#   '<start> young boy overlooking crowd of inflatable boats <end>',
#   '<start> young boy wearing jersey looks down over ledge at many boats in the water <end>'],
#  '1042590306_95dea0916c.jpg': ['<start> man and woman pose for the camera while another man looks on <end>',
#   '<start> man is holding the hand of woman up to his mouth in front of some buildings while another man looks on <end>',
#   '<start> multiracial couple posing for picture <end>',
#   '<start> asian man and blond woman holding hands outdoors man in background watches <end>',
#   '<start> guy in blue shirt biting hand of girl in black striped jacket while another guy watches <end>'],
#  '1048710776_bb5b0a5c7c.jpg': ['<start> couple of several people sitting on ledge overlooking the beach <end>',
#   '<start> group of people sit on wall at the beach <end>',
#   '<start> group of teens sit on wall by beach <end>',
#   '<start> crowd of people at the beach <end>',
#   '<start> several young people sitting on rail above crowded beach <end>'],
#  '1052358063_eae6744153.jpg': ['<start> boy takes jump on his skateboard while another boy with skateboard watches <end>',
#   '<start> child is performing skateboard trick while another child with skateboard leans on wall <end>',
#   '<start> little boy skateboarder is doing trick on his board while another young skateboarder watches <end>',
#   '<start> young boy skateboarder jumping on platform on skateboard <end>',
#   '<start> two skateboarders <end>'],
#  '105342180_4d4a40b47f.jpg': ['<start> girl paddling down large river as seen from behind her <end>',
#   '<start> woman kayaking down river <end>',
#   '<start> woman paddles boat down river <end>',
#   '<start> woman with paddle <end>',
#   '<start> woman with paddle sits in boat on the water <end>'],
#  '1053804096_ad278b25f1.jpg': ['<start> girl in pigtails splashes in the shallow water <end>',
#   '<start> girls plays in the surf <end>',
#   '<start> girl with pigtails is playing in the ocean by the beach <end>',
#   '<start> girl with pigtails plays in the water <end>',
#   '<start> young girl in pigtails plays in the water <end>'],
#  '1055623002_8195a43714.jpg': ['<start> group of four children wearing pajamas have pillow fight <end>',
#   '<start> group of kids have pillow fight <end>',
#   '<start> group of young children playing pillow fight on bed <end>',
#   '<start> children having pillow fight <end>',
#   '<start> four children are having pillow fight <end>'],
#  '1055753357_4fa3d8d693.jpg': ['<start> two constructions workers sit on beam taking break <end>',
#   '<start> two construction workers are sitting up on the side of building <end>',
#   '<start> two construction workers sitting on an beam <end>',
#   '<start> two construction workers take seat on steel beam <end>',
#   '<start> two men take break from construction <end>'],
#  '1056359656_662cee0814.jpg': ['<start> little girl looking at brochure on train rides <end>',
#   '<start> young blond girl with magizine in her hands <end>',
#   '<start> young girl on train reads book about train rides <end>',
#   '<start> young girl sits on seat and looks at train pamphlet <end>',
#   '<start> child sitting down looking at train ride brochure <end>'],
#  '1056873310_49c665eb22.jpg': ['<start> brown dog is running after black dog on rocky shore <end>',
#   '<start> brown dog is running after the black dog <end>',
#   '<start> two dogs playing on beach <end>',
#   '<start> two dogs run across stones near body of water <end>',
#   '<start> two dogs run towards each other on rocky area with water in the background <end>'],
#  '1057089366_ca83da0877.jpg': ['<start> boy descends off the end of high diving board <end>',
#   '<start> child jumps off high diving board into the pool <end>',
#   '<start> kid jumps off the diving board and into the swimming pool below <end>',
#   '<start> little kid is jumping off high dive at the pool <end>',
#   '<start> the boy is jumping off high diving board into the pool <end>'],
#  '1057210460_09c6f4c6c1.jpg': ['<start> guy stands by window taking his overshirt off <end>',
#   '<start> man in tank top stands next to chrome door <end>',
#   '<start> man puts his shirt on near an elevator <end>',
#   '<start> man stands by an elevator with his head down <end>',
#   '<start> the man is putting on his shirt near an elevator <end>'],
#  '1057251835_6ded4ada9c.jpg': ['<start> light colored dog runs on the beach <end>',
#   '<start> small yellow dog runs on beach <end>',
#   '<start> tan dog runs on sandy beach <end>',
#   '<start> white dog is running down rocky beach <end>',
#   '<start> light brown dog running along the beach <end>'],
#  '106514190_bae200f463.jpg': ['<start> hiker standing high on bluff overlooking the mountains below <end>',
#   '<start> person on ski looks from hill over snow covered landscape <end>',
#   '<start> skier is overlooking snow covered mountain <end>',
#   '<start> skier is overlooking the beautiful white snow covered landscape <end>',
#   '<start> skier pauses on mountaintop <end>'],
#  '1067180831_a59dc64344.jpg': ['<start> black and white dog is attempting to catch yellow and purple object in low cut yard <end>',
#   '<start> black and white dog jumps after yellow toy <end>',
#   '<start> black and white dog jumps to get the frisbee <end>',
#   '<start> black dog is jumping up to catch purple and green toy <end>',
#   '<start> dog jumps to catch toy <end>'],
#  '1067675215_7336a694d6.jpg': ['<start> man in blue shorts is laying in the street <end>',
#   '<start> man in blue shorts lays down outside in parking lot <end>',
#   '<start> man laying down in middle of street during heavy traffic <end>',
#   '<start> man lies on mat in parking lot between brown suv and yellow pickup with an open door <end>',
#   '<start> shirtless man is laying down in the middle of busy street <end>'],
#  '1067790824_f3cc97239b.jpg': ['<start> white and black dog and brown dog in sandy terrain <end>',
#   '<start> woolly dog chases doberman on beach <end>',
#   '<start> one dog is chasing another one on the beach <end>',
#   '<start> the two large dogs are running through sand <end>',
#   '<start> two large dogs chasing each other at the beach <end>'],
#  '1072153132_53d2bb1b60.jpg': ['<start> black and white dog catches toy in midair <end>',
#   '<start> dog and tennis ball <end>',
#   '<start> dog is jumping to catch object thrown at it <end>',
#   '<start> dog leaps while chasing tennis ball through grassy field <end>',
#   '<start> multicolor dog jumping to catch tennis ball in grassy field <end>'],
#  '107318069_e9f2ef32de.jpg': ['<start> crowd watching air balloons at night <end>',
#   '<start> group of hot air balloons lit up at night <end>',
#   '<start> people are watching hot air balloons in the park <end>',
#   '<start> people watching hot air balloons <end>',
#   '<start> seven large balloons are lined up at nighttime near crowd <end>'],
#  '1075716537_62105738b4.jpg': ['<start> child with helmet on his head rides bike <end>',
#   '<start> little boy rides bike down hill on miniature dirt bike <end>',
#   '<start> young boy in helmet rides bike on the road <end>',
#   '<start> the little boy rides his bicycle in race <end>',
#   '<start> the young boy pedals quickly at bmx race <end>'],
#  '1075867198_27ca2e7efe.jpg': ['<start> man in brown shirt and dark shorts plays on the beach with his two black dogs <end>',
#   '<start> man in shorts with two black dogs holds ball throwing toy at the beach <end>',
#   '<start> man playing with two black dogs on the beach <end>',
#   '<start> man with two dogs on beach <end>',
#   '<start> man at the beach with two dogs <end>'],
#  '1075881101_d55c46bece.jpg': ['<start> boy cleans the bubbles off his face <end>',
#   '<start> boy covered in suds has his face wiped clean <end>',
#   '<start> boy is covered in bubbles <end>',
#   '<start> child covered in foam is climbing on black inflatable ramp <end>',
#   '<start> person covered in soapy water is getting cleaned off <end>'],
#  '1079274291_9aaf896cc1.jpg': ['<start> little boy sticks his tongue out for the camera another boy looks on <end>',
#   '<start> two boys make faces <end>',
#   '<start> two young boys are looking at the camera one smiling the other sticking his tongue out <end>',
#   '<start> two young boys look up at the camera as one sticks out his tongue <end>',
#   '<start> two young boys making silly faces <end>'],
#  '10815824_2997e03d76.jpg': ['<start> blonde horse and blonde girl in black sweatshirt are staring at fire in barrel <end>',
#   '<start> girl and her horse stand by fire <end>',
#   '<start> girl holding horse lead behind fire <end>',
#   '<start> man and girl and two horses are near contained fire <end>',
#   '<start> two people and two horses watching fire <end>'],
#  '1082252566_8c79beef93.jpg': ['<start> bulldog sheep dog and boxer standing in yard <end>',
#   '<start> large brown dog is pushing small boston terrier with his face while anouther dog watches <end>',
#   '<start> large skinny dog stands near two smaller dogs int the dirt <end>',
#   '<start> there are three dogs starring at ball in the middle of them <end>',
#   '<start> three dogs of various sizes <end>'],
#  '1084104085_3b06223afe.jpg': ['<start> woman in yellow shirt and green shorts is climbing an artificial red wall whilst wearing safety harness <end>',
#   '<start> woman in blue shorts and white shirt is indoor rock climbing <end>',
#   '<start> the girl is climbing rock wall <end>',
#   '<start> the girl is in harness climbing rocks <end>',
#   '<start> woman climbing an artificial rock wall <end>'],
#  '1087168168_70280d024a.jpg': ['<start> boy is jumping on an inflatable ring and girl is watching him <end>',
#   '<start> boy jumping on water jumphouse <end>',
#   '<start> teenage boy is jumping on an inflatable slide <end>',
#   '<start> young boy jumping and young girl seating in an inflatable pool <end>',
#   '<start> two young kids are playing in the water on an inflated toy <end>'],
#  '108898978_7713be88fc.jpg': ['<start> skiiers walking up the hill through forest <end>',
#   '<start> two men are skiing in the snow in wooded area <end>',
#   '<start> two people wearing yellow jackets cross country skiing <end>',
#   '<start> two skiers are making their way through woodland <end>',
#   '<start> two skiers are sliding down trail in the woods <end>'],
#  '108899015_bf36131a57.jpg': ['<start> lone skier is making their way up mountain <end>',
#   '<start> skiiers at the top of snow covered hill <end>',
#   '<start> two hikers climbing snowy hill <end>',
#   '<start> two people are on snow covered mountain <end>',
#   '<start> two people climbing up snowy mountain <end>'],
#  '1089181217_ee1167f7af.jpg': ['<start> brown dog running down paved pathway <end>',
#   '<start> brown dog running next to grass <end>',
#   '<start> dog is running down road <end>',
#   '<start> light brown dog runs down path happily <end>',
#   '<start> energetic brown dog running <end>'],
#  '109202756_b97fcdc62c.jpg': ['<start> woman dressed in blue jacket and blue jeans rides brown horse near frozen lake and snow covered mountain <end>',
#   '<start> woman in blue jacket rides brown pony near water <end>',
#   '<start> woman rides horse near frozen lake in the wintertime <end>',
#   '<start> young blond woman sitting atop brown draft horse in the snowy mountains <end>',
#   '<start> woman blue jacket sits on daft horse near frozen lake <end>'],
#  '109202801_c6381eef15.jpg': ['<start> two draft horses pull cart through the snow <end>',
#   '<start> two golden brown horses pull sleigh driven by woman in blue coat <end>',
#   '<start> two horses are pulling woman in cart <end>',
#   '<start> two horses pull carriage driven by woman over snow covered ground <end>',
#   '<start> two horses pulling sled steered by smiling blond woman <end>'],
#  '109260216_85b0be5378.jpg': ['<start> person climbing down sheer rock cliff using rope <end>',
#   '<start> person climbs tall flat mountain while holding onto safety rope <end>',
#   '<start> person is climbing rock while holding onto white rope <end>',
#   '<start> person rappels down steep incline <end>',
#   '<start> person wearing red vest climbs up steep rock <end>'],
#  '109260218_fca831f933.jpg': ['<start> people stand inside rock dome <end>',
#   '<start> shaft of light in cave shows three spelunkers <end>',
#   '<start> spelunkers pose inside rock cavern while bathed in sunlight from the surface <end>',
#   '<start> three people sit in cave <end>',
#   '<start> three rock climbers are posing on big rocks <end>'],
#  '1093716555_801aacef79.jpg': ['<start> group of backpackers lay on the dry ground <end>',
#   '<start> group of hikers are resting on the ground in front of some mountains <end>',
#   '<start> people camp with the mountains in the background <end>',
#   '<start> several hikers rest with their gear in front of mountain <end>',
#   '<start> the group of hikers is resting in front of mountain <end>'],
#  '1093737381_b313cd49ff.jpg': ['<start> woman in blue dress stands with chalk portrait of two children playing by stream <end>',
#   '<start> woman standing in front of chalk drawing <end>',
#   '<start> woman stands next to chalk drawing in front of barn like structure <end>',
#   '<start> woman stands outside near an elaborate chalk illustration <end>',
#   '<start> woman wearing blue dress is drawing picture of boy and girl on the sidewalk with sidewalk chalk <end>'],
#  '1094462889_f9966dafa6.jpg': ['<start> brown dog plays in deep pile of snow <end>',
#   '<start> dog looking at the camera in snow <end>',
#   '<start> dog runs through the snow <end>',
#   '<start> tan dog stand in the snow and looks up <end>',
#   '<start> the brown dog is out in the snow <end>'],
#  '1095476286_87d4f8664e.jpg': ['<start> boy jumping in fountain <end>',
#   '<start> boy plays in the fountains <end>',
#   '<start> child plays in fountain <end>',
#   '<start> little boy playing in the water <end>',
#   '<start> young boy is jumping through water being sprayed up from the ground <end>'],
#  '1095580424_76f0aa8a3e.jpg': ['<start> corgi runs out of tunnel <end>',
#   '<start> dog runs out of tunnel on course <end>',
#   '<start> dog running out of tunnel on obstacle course <end>',
#   '<start> the dog is running out of the tunnel on dog obedience course <end>',
#   '<start> the small brown and white dog is running out of small tunnel <end>'],
#  '1095590286_c654f7e5a9.jpg': ['<start> blond dog and black and white dog run in dirt field <end>',
#   '<start> dog chases another dog <end>',
#   '<start> yellow dog and black and white dog are running in the dirt <end>',
#   '<start> two dogs are running in field <end>',
#   '<start> two dogs running around <end>'],
#  '1095980313_3c94799968.jpg': ['<start> little girl in blue swimsuit is walking along wooden fence next to sandy beach <end>',
#   '<start> little girl with arms outstretched is posing at the beach <end>',
#   '<start> young girl walks on railing in front of the beach <end>',
#   '<start> little girl in blue swimsuit standing on handrail near beach <end>',
#   '<start> the little girl in the blue bathing suit is posing at the beach <end>'],
#  '1096097967_ac305887b4.jpg': ['<start> black and white dog drinking water from water spray <end>',
#   '<start> black and white dog is being soaked with jet of water in blue paddling pool <end>',
#   '<start> dog sticking its face into the shower from garden hose <end>',
#   '<start> small white dog gets sprayed by water <end>',
#   '<start> white and black dog is jumping into pool <end>'],
#  '1096165011_cc5eb16aa6.jpg': ['<start> boy smiles underwater <end>',
#   '<start> red headed boy swimming underwater <end>',
#   '<start> small boy swimming underwater <end>',
#   '<start> smiling boy swims underwater in pool <end>',
#   '<start> the boys smiles underwater at the pool <end>'],
#  '109671650_f7bbc297fa.jpg': ['<start> boy in yellow shorts is standing on top of cliff <end>',
#   '<start> boy wearing blue and yellow walking on cliff edge <end>',
#   '<start> little boy standing high in the air on rock <end>',
#   '<start> young child is standing alone on some jagged rocks <end>',
#   '<start> child stands near edge of cliff <end>'],
#  '109738763_90541ef30d.jpg': ['<start> person on snowmobile in mid jump <end>',
#   '<start> snowmobiler flies through the air <end>',
#   '<start> snowmobile rider flies through the air on his or her machine in front of tall pine trees <end>',
#   '<start> rider jumps snowmobile high in rural area <end>',
#   '<start> the man is up in the air <end>'],
#  '109738916_236dc456ac.jpg': ['<start> people are riding around on snowmobiles <end>',
#   '<start> people pose with helmets and goggles on while riding snowmobiles <end>',
#   '<start> several people are taking break while on snowmobiling ride <end>',
#   '<start> three people and two snowmobiles <end>',
#   '<start> two helmeted men sit on yellow snowmobiles while another man stands behind watching <end>'],
#  '109823394_83fcb735e1.jpg': ['<start> three people drive atvs <end>',
#   '<start> three people on atvs in brown field turn their heads to look at the camera <end>',
#   '<start> three people on atv outside <end>',
#   '<start> three people on four wheel atv in field <end>',
#   '<start> three people ride their four wheelers through the field <end>'],
#  '109823395_6fb423a90f.jpg': ['<start> four wheeler jumping in an empty field <end>',
#   '<start> man on four wheeler is flying through the air <end>',
#   '<start> person is riding an orange atv in large empty field <end>',
#   '<start> man jumping with all terrain vehicle <end>',
#   '<start> man on an atv catching air <end>'],
#  '109823397_e35154645f.jpg': ['<start> man jumps gin the air while riding an atv <end>',
#   '<start> man on four wheeler jumps near small building <end>',
#   '<start> an atv is airborne over field in front of white structure <end>',
#   '<start> person dressed in tan jacket jumps quad over harvested cornfield in front of small out building <end>',
#   '<start> man on four wheeler in the air <end>'],
#  '1104133405_c04a00707f.jpg': ['<start> boy carrying soccer ball <end>',
#   '<start> boy walks with ball tucked under his arm <end>',
#   '<start> boy walks with soccer ball near fence <end>',
#   '<start> boy wearing white shirt walks on the grass and carries soccer ball <end>',
#   '<start> small boy carries soccer ball on field <end>'],
#  '1105959054_9c3a738096.jpg': ['<start> child painting picture <end>',
#   '<start> an artist paints clouds onto canvas <end>',
#   '<start> young girl painting picture <end>',
#   '<start> young girl with braids is painting with water colors on white paper on the wall <end>',
#   '<start> the child paints on large paper with water colors <end>'],
#  '110595925_f3395c8bd6.jpg': ['<start> cyclist is riding bicycle on curved road up hill <end>',
#   '<start> man in aerodynamic gear riding bicycle down road around sharp curve <end>',
#   '<start> man on mountain bike is pedaling up hill <end>',
#   '<start> man bicycle up road while cows graze on hill nearby <end>',
#   '<start> the biker is riding around curve in the road <end>'],
#  '1107471216_4336c9b328.jpg': ['<start> little girl is holding cine camera in front of her face <end>',
#   '<start> young girl is looking through an old fashioned video camera <end>',
#   '<start> young girl steadies her aim with camera <end>',
#   '<start> girl with rosy cheeks and lips holding black toy gun <end>',
#   '<start> there is kid with gun <end>'],
#  '1110208841_5bb6806afe.jpg': ['<start> black and white border collie catches frisbee in front of an audience <end>',
#   '<start> brown and white dog catches frisbee in it mouth in front of group of people <end>',
#   '<start> brown and white dug jumping up to catch frisbee while an audience watches <end>',
#   '<start> dog jumps to catch frisbee while many people watch <end>',
#   '<start> an agile dog catches frisbee while crowd of onlookers watches closely <end>'],
#  '1112212364_0c48235fc2.jpg': ['<start> baby is sitting on and playing with smooth rocks <end>',
#   '<start> baby is stacking rocks on the beach <end>',
#   '<start> small boy is playing with rocks <end>',
#   '<start> toddler sitting on pile of rocks holding rock at beach <end>',
#   '<start> toddler sits on pile of rocks <end>'],
#  '111537217_082a4ba060.jpg': ['<start> man climbing rock wall <end>',
#   '<start> man climbing the side of cliff <end>',
#   '<start> man is rock climbing <end>',
#   '<start> man with red shoes white shirt and grey pants climbing <end>',
#   '<start> the young man with the white shirt and jeans is rappeling up the rock wall <end>'],
#  '111537222_07e56d5a30.jpg': ['<start> climber wearing blue helmet and headlamp is attached to rope on the rock face <end>',
#   '<start> man climbs rocky wall <end>',
#   '<start> rock climber climbs large rock <end>',
#   '<start> woman in purple snakeskin pants climbs rock <end>',
#   '<start> person with blue helmet and purple pants is rock climbing <end>'],
#  '1115565519_d976d4b1f1.jpg': ['<start> child playing with fountain at the beach <end>',
#   '<start> child plays with fountain <end>',
#   '<start> girl looks at fountain that sprays water <end>',
#   '<start> little girl playing in water on frog sculpture <end>',
#   '<start> the little girl is playing with toy in public fountain <end>'],
#  '1115679311_245eff2f4b.jpg': ['<start> black dog is jumping over log along beach <end>',
#   '<start> black dog runs along the beach and jumps over wood barrior <end>',
#   '<start> dog is running on the beach <end>',
#   '<start> dog jumping over small wall at beach near the water <end>',
#   '<start> an animal is running on the beach <end>'],
#  '111766423_4522d36e56.jpg': ['<start> black and white bird eating seeds out of someone hand <end>',
#   '<start> black and white bird standing on hand <end>',
#   '<start> small bird sits in person hand and eats seeds <end>',
#   '<start> black and white bird standing on hand of someone holding sunflower seeds <end>',
#   '<start> the small bird is clinging to finger of the hand holding the seeds <end>'],
#  '1117972841_2b9261f95f.jpg': ['<start> brown dog is running in the sand <end>',
#   '<start> brown dog playing in the sand <end>',
#   '<start> brown dog plays at the beach <end>',
#   '<start> dog is standing in the sand <end>',
#   '<start> dog running fast in the sand <end>'],
#  '1118557877_736f339752.jpg': ['<start> little boy stands in the surf <end>',
#   '<start> small child wades through the water while being guided by another person <end>',
#   '<start> young boy laughs while splashing in the ocean <end>',
#   '<start> young boy wearing colorful bathing suit splashing in the ocean <end>',
#   '<start> young child splashing in water <end>'],
#  '1119418776_58e4b93eac.jpg': ['<start> black and white dog is running through the field <end>',
#   '<start> black brown and white dog running through field <end>',
#   '<start> brown black and white dog is running through large field with its mouth open <end>',
#   '<start> dog running in field <end>',
#   '<start> dog with its mouth open running through field torwards the camera <end>'],
#  '1119463452_69d4eecd08.jpg': ['<start> girl in pink swimsuit in pool <end>',
#   '<start> girl swimming in pool <end>',
#   '<start> little girl in pink bathing suit swimming in pool <end>',
#   '<start> little girl swimming in pool <end>',
#   '<start> smiling little girl swimming in outdoor pool <end>'],
#  '1121416483_c7902d0d49.jpg': ['<start> child is standing on her head <end>',
#   '<start> little girl standing on her head <end>',
#   '<start> small child doing handstand on bed <end>',
#   '<start> young girl does handstand on bed with blue sheets <end>',
#   '<start> the girl is upside down on bed <end>'],
#  '112178718_87270d9b4d.jpg': ['<start> guy stands in the sand with snowboard behind him <end>',
#   '<start> man holds surfboard on the beach <end>',
#   '<start> man holds his snowboard in the sand <end>',
#   '<start> man with his surfboard stands in the sand <end>',
#   '<start> man is standing on white sand and holding snowboard <end>'],
#  '112243673_fd68255217.jpg': ['<start> people on atvs and dirt bikes are traveling along worn path in field surrounded by trees <end>',
#   '<start> three people are riding around on atv and motorcycles <end>',
#   '<start> three people on motorbikes follow trail through dry grass <end>',
#   '<start> three people on two dirt bikes and one four wheeler are riding through brown grass <end>',
#   '<start> three people ride off road bikes through field surrounded by trees <end>'],
#  '1124448967_2221af8dc5.jpg': ['<start> half naked man is sleeping on his chair outdoors <end>',
#   '<start> an older man sits back and relaxes on patio outside an adobe building where many bicycles are propped <end>',
#   '<start> shirtless man in white cap relaxes in deck chair close to three parked bicycles <end>',
#   '<start> man relaxing in folding chair on the street <end>',
#   '<start> topless old man wearing slippers navy blue pants and white hat while reclining in chair outside <end>'],
#  '1129704496_4a61441f2c.jpg': ['<start> brown and white and black and white dog hauling in floating toy from the ocean <end>',
#   '<start> both dogs retrieve the play toy from the water <end>',
#   '<start> two dogs in the ocean playing with toy <end>',
#   '<start> two dogs run through the water with rope in their mouths <end>',
#   '<start> two dogs tug at chew toy in the surf <end>'],
#  '1130017585_1a219257ac.jpg': ['<start> there are three young people one dark haired holding bottled drink one with head tilted back and finger in her mouth and one with spiked hair <end>',
#   '<start> the young people party in the streets <end>',
#   '<start> three girls make faces as one takes drink while they stand in busy street <end>',
#   '<start> three women on the street drinking and posing <end>',
#   '<start> three young women pose for the camera at parade <end>'],
#  '1130401779_8c30182e3e.jpg': ['<start> two brown dogs are creating large splashes as they run in river <end>',
#   '<start> two brown dogs in the water <end>',
#   '<start> two brown dogs running through water <end>',
#   '<start> two brown dogs runs through the water <end>',
#   '<start> two dogs splash through the water <end>'],
#  '1131340021_83f46b150a.jpg': ['<start> young boy runs while wearing sandals <end>',
#   '<start> little boy in striped shirt and brown shorts is running <end>',
#   '<start> the little boy in short sleeved shirt and shorts is running outside <end>',
#   '<start> the little boy is wearing black pinstripe shirt and walking on deck <end>',
#   '<start> young boy running outside on the pavement <end>'],
#  '1131804997_177c3c0640.jpg': ['<start> two men are sitting on the ground and going through their backpacks <end>',
#   '<start> two men sitting in front of railing are looking at something <end>',
#   '<start> two men with backpacks placed in front of them sitting in front of railing <end>',
#   '<start> two men with backpacks are sitting on cardboard along railing <end>',
#   '<start> two older men with backpacks sit at bus station <end>'],
#  '1132772170_600610c5df.jpg': ['<start> child leaping from bed to bed behind the back of man <end>',
#   '<start> man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room <end>',
#   '<start> man wearing yellow shirt standing in the middle of two beds that boy is jumping on in the background <end>',
#   '<start> young child jumping on the bed as man looks the other way <end>',
#   '<start> man standing in the bedroom with little boy jumping into bed <end>'],
#  '1141718391_24164bf1b1.jpg': ['<start> bridge through high green plants man and woman on it <end>',
#   '<start> man and woman are crossing over rope bridge with greenery all over them <end>',
#   '<start> man and woman are walking across rope bridge <end>',
#   '<start> man and woman crossing suspension bridge in tropical setting <end>',
#   '<start> woman and man walking across wooden rope bridge with caution sign beside it <end>'],
#  '1141739219_2c47195e4c.jpg': ['<start> family gathered at painted van <end>',
#   '<start> girl climbing down from the side of bright blue truck while others watch <end>',
#   '<start> man is helping girl step down from colorful truck whilst woman and three children watch <end>',
#   '<start> very colorful bus is pulled off to the side of the road as its passengers load <end>',
#   '<start> two women and four children standing next to brightly painted truck <end>'],
#  '1142283988_6b227c5231.jpg': ['<start> blond woman poses with person in pink costume <end>',
#   '<start> smiling woman holds person dressed in pig costume <end>',
#   '<start> young woman hugs young man who wearing pink costume <end>',
#   '<start> blond embracing young man in pink costume at event <end>',
#   '<start> two people are hugging and one is wearing pink hooded stretch top <end>'],
#  '1142847777_2a0c1c2551.jpg': ['<start> bicyclist riding on city street <end>',
#   '<start> woman in blue helmet and brown shorts rides her bike on busy street <end>',
#   '<start> woman is riding blue bike <end>',
#   '<start> woman is riding her bicycle in traffic <end>',
#   '<start> woman wearing blue helmet rides her bicycle in parking lot <end>'],
#  '1143373711_2e90b7b799.jpg': ['<start> bicycle rider is crossing street <end>',
#   '<start> bicyclist getting ready to cross street <end>',
#   '<start> biker in spandex riding on busy street <end>',
#   '<start> man in blue and white biking gear rides down busy street <end>',
#   '<start> man wearing helmet riding his bicycle down the street <end>'],
#  '1143882946_1898d2eeb9.jpg': ['<start> lady wearing helmet holding bike <end>',
#   '<start> woman in blue vest and sky blue helmet stands with her bicycle in traffic <end>',
#   '<start> woman in helmet rides her bike behind car <end>',
#   '<start> woman with helmet and backpack walks next to her bike <end>',
#   '<start> women with bike and helmet wait for traffic <end>'],
#  '1144288288_e5c9558b6a.jpg': ['<start> man in shorts is jogging along street with headset <end>',
#   '<start> person in blue shorts and wearing walkman jogs <end>',
#   '<start> woman in white shirt and blue shorts is wearing headphones <end>',
#   '<start> woman walks on street wearing headphones <end>',
#   '<start> woman wearing white hat and shirt is jogging down street with plant store on the corner <end>'],
#  '1148238960_f8cacec2fc.jpg': ['<start> bicyclists are standing at an intersection <end>',
#   '<start> bicyclists waiting at an intersection <end>',
#   '<start> people on bicycles waiting at an intersection <end>',
#   '<start> people waiting at light on bikes <end>',
#   '<start> three bikers stop in town <end>'],
#  '1149179852_acad4d7300.jpg': ['<start> man without shirt on is guiding large brown horse pulling green and yellow wagon <end>',
#   '<start> shirtless man escorts horse pulling carriage along paved road <end>',
#   '<start> shirtless man leading horse that is pulling carriage <end>',
#   '<start> shirtless man leading small horse drawn covered wagon down road <end>',
#   '<start> the shirtless man is walking the shetland pony and carriage down the street <end>'],
#  '114949897_490ca7eaec.jpg': ['<start> boy hits ball off of tee ball into to net <end>',
#   '<start> child practices hitting baseball into net while two adult men watch <end>',
#   '<start> man holds net while boys bats ball into it <end>',
#   '<start> the man is holding the net for the boy playing baseball <end>',
#   '<start> three people put up batting cage <end>'],
#  '1151466868_3bc4d9580b.jpg': ['<start> small girl spins in the waves in the bright sun <end>',
#   '<start> young girl plays in shallow water <end>',
#   '<start> young girl wears shirt and shorts as she plays in the ocean surf <end>',
#   '<start> girl running through the water near the shore <end>',
#   '<start> the little girl splashes through the water <end>'],
#  '1153704539_542f7aa3a5.jpg': ['<start> girl playing trumpet in marching band <end>',
#   '<start> teenager plays her trumpet on the field at game <end>',
#   '<start> young girl wearing blue shirt marching in band playing trumpet <end>',
#   '<start> girl playing the trumpet in marching band <end>',
#   '<start> girl wearing blue shirt and black shorts plays trumped outside <end>'],
#  '1159574340_99ba8c3c59.jpg': ['<start> child jumping into lake in wooded area while another child plays on the shore <end>',
#   '<start> child jumps into the water with his sneakers on <end>',
#   '<start> kid jumping into pool of water <end>',
#   '<start> little boy in sneakers jumping into water <end>',
#   '<start> the man takes leap into the water with his shoes on <end>'],
#  '1160034462_16b38174fe.jpg': ['<start> elderly man in straw hat is sitting on bench <end>',
#   '<start> elderly man sits alone on park bench <end>',
#   '<start> an old man in straw hat sits on park bench <end>',
#   '<start> the old man in the brown hat is sitting on the bench <end>',
#   '<start> white haired man in gray sweater and straw hat sitting on bench under tree <end>'],
#  '1160441615_fe6b3c5277.jpg': ['<start> three girls are walking across bridge covered with wood and surrounded by trees <end>',
#   '<start> three girls walking along an arched garden pathway <end>',
#   '<start> three girls walk under an arbor on path surrounded by trees <end>',
#   '<start> three women walking through tunnel in park <end>',
#   '<start> three women walk through plant covered atrium hallway <end>'],
#  '1163282319_b729b24c46.jpg': ['<start> girl dressed in red top red cap and light colored shorts sits on rock outside <end>',
#   '<start> little girl in red hat and yellow flip flops sits on rock <end>',
#   '<start> little girl with red hood and shirt is sitting with legs sprawled on rock her mouth open <end>',
#   '<start> young girl wearing yellow flip flops is sitting on large boulder <end>',
#   '<start> the little girl sits on top of rock <end>'],
#  '116409198_0fe0c94f3b.jpg': ['<start> man eats near tent in the snow <end>',
#   '<start> man sitting near tent in the snow and ice <end>',
#   '<start> mountaineer sits in the snow in front of yellow tent under clear blue sky <end>',
#   '<start> person wearing hooded jacket sitting on snow in front of yellow tent <end>',
#   '<start> young man in hooded jacket sitting on snow in mountain area <end>'],
#  '1164765687_7aca07bbe7.jpg': ['<start> man in red shirt and glasses is bending down towards small dog on blanket with several stuffed animals <end>',
#   '<start> man in red shirt is giving toys to small dog <end>',
#   '<start> man is playing tug of war with his dog <end>',
#   '<start> man playing with black dog on white blanket <end>',
#   '<start> man playing with his dog on the blanket on the floor <end>'],
#  '1167662968_e466f1e80a.jpg': ['<start> guy with nose piercing <end>',
#   '<start> man in red cap with nose ring <end>',
#   '<start> teenage boy has silver ring protruding from his nose <end>',
#   '<start> closeup picture of man with nose ring and brown shirt <end>',
#   '<start> young man with nose ring and hat <end>'],
#  '1167908324_8caab45e15.jpg': ['<start> man is standing by group of video games in bar <end>',
#   '<start> man standing in bar with neon beer sign hanging on the wall <end>',
#   '<start> man stands next to bank of computer gambling machines <end>',
#   '<start> man stands next to three video game machines and beer sign <end>',
#   '<start> man stands next to three video machines <end>'],
#  '1169307342_e7a4685a5c.jpg': ['<start> big brown dog plays with smaller grey dog on the grass <end>',
#   '<start> the dark brown dog is playing with the light brown dog <end>',
#   '<start> two brown dogs are running through the grass <end>',
#   '<start> two brown dogs run side by side <end>',
#   '<start> two dogs running and playing rough in the grass <end>'],
#  '1176580356_9810d877bf.jpg': ['<start> big dog catches ball on his nose <end>',
#   '<start> brown and black dog is jumping to catch red ball <end>',
#   '<start> brown and black dog jumps for red ball <end>',
#   '<start> dog jumps to get orange ball on his head <end>',
#   '<start> the brown and black dog is jumping up to catch red ball <end>'],
#  '118187095_d422383c81.jpg': ['<start> parents are pushing little children in red car carts <end>',
#   '<start> twin boys being pushed in small car shaped strollers in parade <end>',
#   '<start> twin toddlers dressed alike being pushed in plastic car strollers in parade <end>',
#   '<start> two children ride in toy cars <end>',
#   '<start> two kids being pushed in car shaped strollers in parade <end>'],
#  '118309463_a532b75be9.jpg': ['<start> boys baseball team wear their uniforms <end>',
#   '<start> small boy smiles as he stands with others wearing the same black hats <end>',
#   '<start> children sporting their florida dolphin caps <end>',
#   '<start> the boys are all wearing the same baseball hats <end>',
#   '<start> three boys wearing florida marlins hats <end>'],
#  '1184967930_9e29ce380d.jpg': ['<start> brown dog running through the grass and flowers <end>',
#   '<start> dog in field <end>',
#   '<start> dog running in field of grass and flowers <end>',
#   '<start> dog running in shrubbery along stream <end>',
#   '<start> dog walks through field <end>'],
#  '1187435567_18173c148b.jpg': ['<start> small brown and black dog <end>',
#   '<start> small brown and black dog playing with toy <end>',
# ...
#   '<start> dog runs through the water with stick while another dog stands there <end>',
#   '<start> two dogs are running through wet grassy area and one is carrying long stick <end>',
#   '<start> two dogs fight over stick in flooded field <end>',
#   '<start> two dogs playing in flooded field with stick <end>'],
#  '2244171992_a4beb04d8e.jpg': ['<start> group of school children walking around outside in their uniforms <end>',
#   '<start> japanese school children are going to class <end>',
#   '<start> japanese school girls walk down the street <end>',
#   '<start> people walk along on the street <end>',
#   '<start> uniformed schoolgirls are walking together on the street <end>'],
#  '2244551043_21b8cca866.jpg': ['<start> four people are lining up to purchase tickets at the theater <end>',
#   '<start> four people standing outside of an outdoor ticket booth <end>',
#   '<start> four people wait outside in line for ticket <end>',
#   '<start> the man and woman at the window are turned around to the man and woman behind them <end>',
#   '<start> two men and two women standing at the window of ticket booth <end>'],
#  '2244613488_4d1f9edb33.jpg': ['<start> four bicyclists ride along dirt road between two wire fences <end>',
#   '<start> four cyclists on country trail are passing by an electricity pylon <end>',
#   '<start> the four bicyclists are riding through the desert <end>',
#   '<start> three bikers bike across the dry land <end>',
#   '<start> three cyclists ride near mountain <end>'],
#  '2245348304_08bc5642f1.jpg': ['<start> man in hat sits outside near some cardboard boxes <end>',
#   '<start> man plays his guitar on the street <end>',
#   '<start> man sits on box and plays guitar in the street <end>',
#   '<start> man sits ourdoors next to cardboard boxes and plays an instrument <end>',
#   '<start> an older musician perfoms on the street behind cardboard box <end>'],
#  '2245618207_fa486ba2b7.jpg': ['<start> child in red jumps on red object while others laugh <end>',
#   '<start> child touching red plastic object with crowd behind him <end>',
#   '<start> girl in crowd laughs and climbs on something <end>',
#   '<start> many children having fun outside near large buildings <end>',
#   '<start> there is girl in red jacket smiling with her hand on red blowup and crowd behind her <end>'],
#  '2245914678_1f82fc3d80.jpg': ['<start> girl with dyed red hair wearing striped clothing talking on cellphone <end>',
#   '<start> girl with read dreadlocks is talking on the phone <end>',
#   '<start> red haired girl with black and white striped shirt talking on cellphone <end>',
#   '<start> woman with bright red hair and striped clothing talks on phone <end>',
#   '<start> woman with red hair and black striped shirt talking on the phone <end>'],
#  '2245916742_73af13c733.jpg': ['<start> man in green holding camera stands between two of the head statues on easter island <end>',
#   '<start> man stands between to large sculptures on field <end>',
#   '<start> man stands by two face structures on easter island <end>',
#   '<start> person stands between two giant statues that look like faces <end>',
#   '<start> person stands next to the easter island statues <end>'],
#  '2246717855_c0c08fe5d2.jpg': ['<start> crowd of young people in winter clothing waiting for the train <end>',
#   '<start> several people are looking at their phones in crowded station <end>',
#   '<start> three japanese people wait for the train <end>',
#   '<start> three people in an asian transportation station are all focused on their cellphones <end>',
#   '<start> three people in jackets holding bags looking at their phones <end>'],
#  '224702241_05af393148.jpg': ['<start> blond dog walks in creek with banks filled with snow <end>',
#   '<start> blonde dog makes his way up an icy stream with snow piled up on the sides <end>',
#   '<start> tan dog walks down stream between mounds of snow <end>',
#   '<start> brown dog walks through river between snowbanks <end>',
#   '<start> the dog walks through the cold water <end>'],
#  '224702242_a62aaa6dff.jpg': ['<start> white dog catching soccer ball midair <end>',
#   '<start> white dog jumps up to catch soccer ball in landscaped grassy yard <end>',
#   '<start> yellow lab jumping up into the air to catch soccer ball <end>',
#   '<start> large white dog jumps in the air to catch black and white soccer ball <end>',
#   '<start> white dog leaping in the air for soccer ball <end>'],
#  '2247138288_7355861203.jpg': ['<start> adults in winter jackets and hats swing brooms at little yellow ball while black dog looks on <end>',
#   '<start> group of people and dog sweeping snow <end>',
#   '<start> group of people playing in the snow with brooms <end>',
#   '<start> group of people with brooms standing in the snow with dog in the forefront <end>',
#   '<start> group of people standing on snow covered ground some are holding brooms there is dog with the group <end>'],
#  '2247192427_5e106f24a9.jpg': ['<start> children play basketball on court <end>',
#   '<start> four young boys play basketball <end>',
#   '<start> several children are playing basketball game on basketball court <end>',
#   '<start> three small boys play basketball indoors <end>',
#   '<start> three small boys playing basketball <end>'],
#  '224766705_b77996527f.jpg': ['<start> caravan of green and red vehicles going up mountain <end>',
#   '<start> line of green and red dune buggys on gravel road near rocks and large pine trees <end>',
#   '<start> line of off road vehicles riding along trail <end>',
#   '<start> long line of off road vehicles on mountain trail <end>',
#   '<start> several off road vehicles are driving down gravel road <end>'],
#  '2249141510_f534708374.jpg': ['<start> boy in red is jumping in playground sand pit <end>',
#   '<start> boy in red jumping into sandbox <end>',
#   '<start> boy in red jumps backward onto the sand at playground <end>',
#   '<start> young boy in red leaping into sand at playground <end>',
#   '<start> young boy wearing bright red outfit jumping into the sand at playground <end>'],
#  '2249264723_d08655d9f2.jpg': ['<start> boy jumps on the bright colored pillows <end>',
#   '<start> little boy is jumping on couch that has yellow and blue cushion resting on it <end>',
#   '<start> young boy jumps on the brown couch in his gray and blue spiderman outfit <end>',
#   '<start> young child jumping onto couch <end>',
#   '<start> little boy wearing gray and blue pajamas jumping on furniture with blue and orange pillow under him <end>'],
#  '2249865945_f432c8e5da.jpg': ['<start> dog plays in the snow <end>',
#   '<start> dog wearing coat looks up from the snow <end>',
#   '<start> small white and grey dog in jacket standing in the snow <end>',
#   '<start> white dog in black coat is standing in the snow <end>',
#   '<start> the white dog stands in the snow wearing black jacket <end>'],
#  '2250555512_71670078f5.jpg': ['<start> dark haired man in his twenties drinks green liquid from plastic mug <end>',
#   '<start> distored image of man drinking green liquid in mug <end>',
#   '<start> man in an oxford shirt drinks from beer mug in an large tent <end>',
#   '<start> man sipping drink <end>',
#   '<start> single man drinking mug of green liquid <end>'],
#  '2250870111_8402d2319d.jpg': ['<start> person is reading magazine on snowing sidewalk <end>',
#   '<start> person wearing jeans and brown coat is reading and smoking on the sidewalk by road covered with dirty snow <end>',
#   '<start> woman reads on newspaper on snow covered street <end>',
#   '<start> woman smokes cigarette and looks at magazine in the middle of snowy road <end>',
#   '<start> woman smoking cigarette is standing next to the road during wintery day <end>'],
#  '2251418114_2b0cd4c139.jpg': ['<start> boy stands on rocky mountain <end>',
#   '<start> child on rock formation <end>',
#   '<start> child sitting on rock formation <end>',
#   '<start> little boy sitts on top of big rock <end>',
#   '<start> person in red jacket on top of rocks <end>'],
#  '2251447809_2de73afcdf.jpg': ['<start> man dressed in black walks on an icy sidewalk <end>',
#   '<start> man walks on the icy sidewalk <end>',
#   '<start> quiet sidewalk in town with view of traffic intersection <end>',
#   '<start> man walking toward his car on an icy sidewalk in the city <end>',
#   '<start> there is man dressed in black walking on sidewalk with melted snow <end>'],
#  '2251992614_0c601fae2c.jpg': ['<start> busy street of people and two men are wearing no shirts <end>',
#   '<start> man walks with his shirt off and rolled up pants in busy city street <end>',
#   '<start> many people are walking in crowded street <end>',
#   '<start> the lady watches the man without shirt <end>',
#   '<start> young people are walking around public square on warm day <end>'],
#  '2252123185_487f21e336.jpg': ['<start> bunch on people are seated in stadium <end>',
#   '<start> crowded stadium is full of people watching an event <end>',
#   '<start> crowd of people fill up packed stadium <end>',
#   '<start> crowd sitting in an indoor stadium <end>',
#   '<start> stadium full of people watch game <end>'],
#  '2252264255_03fefc25af.jpg': ['<start> two boys eating apples playing on cement car barrier <end>',
#   '<start> two boys with apples leap over barrier in the street <end>',
#   '<start> two little boys eating apples climing over retaining wall <end>',
#   '<start> two little boys holding apples near the street <end>',
#   '<start> two young boys with apples hop concrete barrier <end>'],
#  '2252299132_14ca6e584b.jpg': ['<start> boy walks <end>',
#   '<start> boy wearing face paint walks along red track <end>',
#   '<start> boy with face paint is running on track <end>',
#   '<start> young boy running race on track with painted face <end>',
#   '<start> boy with painted face is walking around track <end>'],
#  '2252403744_148fc11f68.jpg': ['<start> an asian girl and boy playing on with yellow ball on black and white floor <end>',
#   '<start> two children play and one has beach ball <end>',
#   '<start> two children play with ball on the floor <end>',
#   '<start> two young children playing with each other and ball <end>',
#   '<start> young girl in pink dress plays with boy and ball <end>'],
#  '2252635585_b48b3485b0.jpg': ['<start> two big dogs play in the snow under tree <end>',
#   '<start> two dogs are playing in the snow next to tree <end>',
#   '<start> two dogs are playing with tennis ball in snow near tree <end>',
#   '<start> two dogs play in the snow on the ground near tree with one on top of the other <end>',
#   '<start> two dogs tussle in the snow over tennis ball <end>'],
#  '2254913901_569f568926.jpg': ['<start> louis vuitton store window at night <end>',
#   '<start> woman looks at clothes in louis vuitton store window <end>',
#   '<start> woman widow shops outside of louis vuitton store <end>',
#   '<start> the woman in black is looking at outfits in clothing store window <end>',
#   '<start> woman on the street window shops in front of the store louis vuitton <end>'],
#  '2255266906_8222af18b9.jpg': ['<start> bird sits in leafless tree <end>',
#   '<start> bird sits in tree <end>',
#   '<start> black bird sits in dead tree <end>',
#   '<start> black bird sitting in leafless tree <end>',
#   '<start> grey dove in bare tree <end>'],
#  '2255332561_3375897ff0.jpg': ['<start> lone man climbing the side of large rock wall <end>',
#   '<start> man is on the side of mountain and hiking around huge rocks <end>',
#   '<start> man stands on the rocky ledge of large cliff <end>',
#   '<start> person stands atop rock face <end>',
#   '<start> the man is on the mountainside <end>'],
#  '2255338013_566127590b.jpg': ['<start> man is abseiling down cliff over the ocean <end>',
#   '<start> man is repelling down cliff next to lake <end>',
#   '<start> man is repelling down the side of mountain over the ocean <end>',
#   '<start> person is swinging by cord over the ocean <end>',
#   '<start> person rappelling cliff above body of water <end>'],
#  '2255342813_5b2ac6d633.jpg': ['<start> person climbing down rocky cliffside with water below <end>',
#   '<start> person repelling on the side of cliff face <end>',
#   '<start> person wearing black with white helmet is going down mountainside with water below <end>',
#   '<start> extreme climbing over ocean <end>',
#   '<start> looking down on someone climbing cliff over water <end>'],
#  '2255685792_f70474c6db.jpg': ['<start> three individuals are posing on skis behind no skiing sign <end>',
#   '<start> three people in skiing gear are standing behind no skiing sign <end>',
#   '<start> three people on skis are standing behind no skiing sign <end>',
#   '<start> three people standing in the snow behind no skiing sign <end>',
#   '<start> three people stand ready to ski next to no skiing sign <end>'],
#  '2256138896_3e24b0b28d.jpg': ['<start> man does technical rock climbing <end>',
#   '<start> man dressed in all black is climbing down mountain supported by cords <end>',
#   '<start> man is climbing the side of cliff <end>',
#   '<start> man wearing white helmet is abseiling down sandy colored rock face <end>',
#   '<start> rock climber with white helmet is repelling <end>'],
#  '2256218522_53b92bcbb2.jpg': ['<start> black and white dog is running through the sand at beach <end>',
#   '<start> black and white dog playing in the sand <end>',
#   '<start> dog bounding across the sandy landscape in front of people watching <end>',
#   '<start> dog lunges across beach <end>',
#   '<start> black dog running across dirt <end>'],
#  '2256231539_05c27179f1.jpg': ['<start> child holds football and runs from other children <end>',
#   '<start> young boy in blue uniform running with football while playing game of flag football <end>',
#   '<start> young boy weating blue shorts and cleats holding football running from other boys <end>',
#   '<start> young male carrying football and running while two other boys run behind him <end>',
#   '<start> the boy in blue runs with the ball whilst being chased by two boys in red <end>'],
#  '2256320794_0286c31bfa.jpg': ['<start> dog is waling on sand <end>',
#   '<start> dog that looks like lassie making funny face <end>',
#   '<start> puppy runs in the sand <end>',
#   '<start> dog has mouth open in field <end>',
#   '<start> the collie is standing outdoors on sandy area <end>'],
#  '2257099774_37d0d3aa9a.jpg': ['<start> an elderly asian woman wearing blue winter coat and red hat in front of food counter <end>',
#   '<start> woman in red cap in store <end>',
#   '<start> woman wearing red hat and black coat <end>',
#   '<start> woman with red hat and face stands in front of jars <end>',
#   '<start> the hapy asian woman is at the market <end>'],
#  '2257294002_0073263c54.jpg': ['<start> the children of family play while they wait <end>',
#   '<start> three asian kids dance while man looks on <end>',
#   '<start> three children do jumping jacks in public place while man sits and looks on <end>',
#   '<start> three children jumping while an older man watches from row of chairs nearby <end>',
#   '<start> three young children jump while an older man watches from his seat <end>'],
#  '2257631407_1529b9db39.jpg': ['<start> couple of playful kids in sweats and jeans romp on the grass <end>',
#   '<start> girl on someone back is laughing <end>',
#   '<start> kids playing around <end>',
#   '<start> someone holding little girl hanging upside down <end>',
#   '<start> two peoplw with top of heads on grass <end>'],
#  '2257798999_d9d1b9a45a.jpg': ['<start> as the brown dog looks the other way large black and white dog plays with smaller black dog <end>',
#   '<start> orange brown and white and brown dogs on grass <end>',
#   '<start> three dogs playing and laying on the grass <end>',
#   '<start> three dogs playing in yard together <end>',
#   '<start> three dogs play together <end>'],
#  '2258662398_2797d0eca8.jpg': ['<start> child in black wetsuit is in the waves on surfboard <end>',
#   '<start> kid on surfboard riding small wave <end>',
#   '<start> small boy in black is surfing <end>',
#   '<start> young boy in black wetsuit surfs in the water <end>',
#   '<start> young surfer rides wave <end>'],
#  ...}

# %%
def dict_to_list(descriptions):
    return [d for key in descriptions for d in descriptions[key]]

def create_tokenizer(descriptions):
    desc_list = dict_to_list(descriptions)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(desc_list)
    return tokenizer
def max_length(descriptions):
    desc_list = dict_to_list(descriptions)
    return max(len(d.split()) for d in desc_list)

tokenizer = create_tokenizer(train_descriptions)
pickle.dump(tokenizer, open('data/tokenizer.p', 'wb'))
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 7318

# %%
print(len(train_imgs))
print(len(train_descriptions))
print(vocab_size)
print(len(train_features))
# Out:
# 6000
# 6000
# 7318
# 6000

# %%
#calculate maximum length of descriptions
def max_length(descriptions):
    desc_list = dict_to_list(descriptions)
    return max(len(d.split()) for d in desc_list)
    
max_length = max_length(descriptions)
max_length
# Out:
# 33

# %% [markdown]
# ##  Create Data generator

# %%
def data_generator(descriptions, features, tokenizer, max_length):
    while True:
        for key, description_list in descriptions.items():
            #retrieve photo features
            feature = features[key][0]
            input_image, input_sequence, output_word = create_sequences(tokenizer, max_length, description_list, feature)
            yield ([input_image, input_sequence], output_word)

def create_sequences(tokenizer, max_length, desc_list, feature):
    x1 = [] 
    x2 = []
    y = []
    for desc in desc_list:
        seq = tokenizer.texts_to_sequences([desc])[0]
        for i in range(1, len(seq)):
            in_seq = seq[:i]
            out_seq = seq[i]
            x1.append(feature)
            x2.append(pad_sequences([in_seq], maxlen=max_length)[0])
            y.append(to_categorical([out_seq], num_classes=vocab_size)[0])
    return np.array(x1), np.array(x2), np.array(y)

#You can check the shape of the input and output for your model
[a,b],c = next(data_generator(train_descriptions, features, tokenizer, max_length))
a.shape, b.shape, c.shape
#((47, 2048), (47, 32), (47, 7577))
# Out:
# ((47, 2048), (47, 33), (47, 7318))

# %% [markdown]
# ## Defining the CNN-GRU model

# %%
# Features squeezed from 2048 to 256 nodes
input1 = Input(shape=(2048,))
dropout_1 = Dropout(0.4)(input1)
dense_1 = Dense(1024, activation="relu")(dropout_1)
dropout_2 = Dropout(0.4)(dense_1)
dense_2 = Dense(256, activation='relu')(dropout_2)

# GRU(Gated Recurrent Units) model
input2 = Input(shape=(max_length,))
embed_1 = Embedding(vocab_size, 256, mask_zero=True)(input2)
dropout_2 = Dropout(0.4)(embed_1)
gru_layer = GRU(256)(dropout_2)

# Merging both models
concat = Concatenate(axis=-1)([dense_2, gru_layer])
dense_comb_1= Dense(256, activation='relu')(concat)
dropout_final = Dropout(0.4)(dense_comb_1)
outputs = Dense(vocab_size, activation='softmax')(dropout_final)

model = Model(inputs=[input1, input2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam')
# Out:
# WARNING:tensorflow:From D:\image_captioning\venv2\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ## TRAINING SECTION

# %%
# train our model
print('Dataset: ', len(train_imgs))
print('Descriptions: train=', len(train_descriptions))
print('Photos: train=', len(train_features))
print('Vocabulary Size:', vocab_size)
print('Description Length: ', max_length)
# Out:
# Dataset:  6000
# Descriptions: train= 6000
# Photos: train= 6000
# Vocabulary Size: 7318
# Description Length:  33

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 2048)]               0         []
#
#  dropout (Dropout)           (None, 2048)                 0         ['input_3[0][0]']
#
#  input_4 (InputLayer)        [(None, 33)]                 0         []
#
#  dense (Dense)               (None, 1024)                 2098176   ['dropout[0][0]']
#
#  embedding (Embedding)       (None, 33, 256)              1873408   ['input_4[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['dense[0][0]']
#
#  dropout_2 (Dropout)         (None, 33, 256)              0         ['embedding[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  262400    ['dropout_1[0][0]']
#
#  gru (GRU)                   (None, 256)                  394752    ['dropout_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 512)                  0         ['dense_1[0][0]',
#  )                                                                   'gru[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  131328    ['concatenate_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 256)                  0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 7318)                 1880726   ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 6640790 (25.33 MB)
# Trainable params: 6640790 (25.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
generator = data_generator(train_descriptions, train_features, tokenizer, max_length)
model.fit_generator(generator, epochs=5, steps_per_epoch=len(train_descriptions), verbose=1)
# Out:
# Epoch 1/5
# C:\Users\91997\AppData\Local\Temp\ipykernel_20744\3966974728.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator, epochs=5, steps_per_epoch=len(train_descriptions), verbose=1)
# 6000/6000 [==============================] - 763s 127ms/step - loss: 4.0500
# Epoch 2/5
# 6000/6000 [==============================] - 747s 125ms/step - loss: 3.8439
# Epoch 3/5
# 6000/6000 [==============================] - 728s 121ms/step - loss: 3.7209
# Epoch 4/5
# 6000/6000 [==============================] - 1139s 190ms/step - loss: 3.6500
# Epoch 5/5
# 6000/6000 [==============================] - 735s 123ms/step - loss: 3.5954
